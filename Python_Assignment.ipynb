# %% [markdown]
# <a href="https://colab.research.google.com/github/sumaiatuljannat/Python_Basic/blob/main/Python_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **No** **01**

# %%
name      = "Sumaiatul Jannat"
                                # str
age       = 20           # int
height    = 164.5      # cm type(float)
is_student = True        # bool
nothing   = None         # NoneType

print(name, age, height, is_student, nothing)
# Out:
# Sumaiatul Jannat 20 164.5 True None

# %% [markdown]
# **Problem 2:  Given x = '42', y = 3.9, z = True - convert x to int, y to int (notice what happens to the decimal), and z to str. Print each converted value and verify its type using type(). **

# %%
# str → int
a = int("100")
print(a, type(a))   # 100 <class int>

# int → float
b = float(10)
print(b, type(b))   # 10.0 <class float>

# int → str
c = str(42)
print(c, type(c))   # "42" <class str>

# float → int (truncates decimal)
d = int(9.99)
print(d)            # 9

# bool conversions
print(int(True), int(False))   # 1 0
print(bool(0), bool(1), bool(""), bool("hi"))  # False True False True
# Out:
# x = 42 <class 'int'>
# y = 3 <class 'int'>
# z = True <class 'str'>

# %% [markdown]
# **Problem 3:  Assign the values 10, 20, 30 to three variables a, b, c in a single line. Then swap a and c without using a temporary variable and print both before and after values.**

# %%
a, b, c = 10, 20, 30
print("Before:", a, b, c)
a, c = c, a  #swapping a and c
print("After:", a, b, c)
# Out:
# Before: 10 20 30
# After: 30 20 10

# %% [markdown]
# **Problem 4:  Show dynamic typing in action: create a variable x, assign an integer to it and print its type, then reassign a string to the same variable and print its type again, then reassign a float and print once more**

# %%
x = 10
print(x, type(x)) #int type
x = "hello"
print(x, type(x)) #string type
x = 3.14
print(x, type(x)) #float type
# Out:
# 10 <class 'int'>
# hello <class 'str'>
# 3.14 <class 'float'>

# %% [markdown]
# **Problem 5:  Try type-converting the following and print the result: bool(0), bool(''), bool('hello'), bool(99), int(True), int(False), float('3.14'). Write one conversion per line with a comment explaining the output.**

# %%
print(bool(0)) # false because 0 is false
print(bool(""))  # false because empty string
print(bool("hello")) # True because non-empty string
print(bool(99)) # True because non-zero number
print(int(True))# 1
print(int(False)) # 0
print(float("3.14"))# 3.14
# Out:
# False
# False
# True
# True
# 1
# 0
# 3.14

# %% [markdown]
# Store any two integers in variables a and b. Print the result of all seven arithmetic operations (+, -, *, /, //, %, **) with a descriptive label for each line. Example: 'Floor division: 3'

# %%
a, b = 20, 15
print(f"{a} + {b} = {a + b}") # Addition
print(f"{a} - {b} = {a - b}")  # Subtraction
print(f"{a} * {b} = {a * b}")  # Multiplication
print(f"{a} / {b} = {a / b}")  # Division (always float)
print(f"{a} // {b} = {a // b}") # Floor Division
print(f"{a} % {b} = {a % b}")  # Modulus
print(f"{a} ** {b} = {a ** b}")  # Exponentiation
# Out:
# 20 + 15 = 35
# 20 - 15 = 5
# 20 * 15 = 300
# 20 / 15 = 1.3333333333333333
# 20 // 15 = 1
# 20 % 15 = 5
# 20 ** 15 = 32768000000000000000

# %% [markdown]
#  **Start with x = 100. Apply these augmented assignment operations in order and print x after each step: subtract 25, multiply by 2, floor-divide by 3, take modulus with 7, raise to power 2.**

# %%
x = 100
x -= 25 #substract

print(x)

x *= 2
print(x) #multiply

x //= 3
print(x) #floor-divide

x %= 7
print(x) #modulus

x **= 2
print(x) #raise to power
# Out:
# 75
# 150
# 50
# 1
# 1

# %% [markdown]
# **Problem 8:  Given a = 15, b = 15, c = [1,2], d = [1,2] - print the result of: a == b, a is b, c == d, c is d. Then explain in a comment why 'is' and '==' give different results for the lists.**

# %%
a = 15
b = 15
c = [1,2]
d = [1,2]

print(a == b)#==compare value
print(a is b)#is locate memory
print(c == d) #==compare value
print(c is d)#is locate memory
# Out:
# True
# True
# True
# False

# %% [markdown]
# **Problem 9:  Write expressions using logical operators to check: (1) a number is between 10 and 50 (inclusive), (2) a string is either 'yes' or 'no', (3) a number is NOT divisible by 2. Test each with sample values and print True/False.**

# %% [markdown]
# print(True and True)   # True
#
# print(True and False)  # False
#
# print(False or True)   # True
#
# print(False or False)  # False
#
# print(not True)        # False
#
# print(not False)       # True

# %%
num = 20
print(num >= 10 and num <= 50)#True
word = "yes"
print(word == "yes" or word == "no")#True
n = 8
print(not (n % 2 == 0)) #False

num = 30
print(num >= 10 and num <= 50)# True
string = 'No'
print(string in ['yes', 'no'])  # True
print(not(num % 2 == 0))  # False
# Out:
# True
# True
# False
# True
# False
# False

# %% [markdown]
#  **10:  Check membership using 'in' and 'not in': (1) is 'py' inside 'python'? (2) is 'z' not in 'python'? (3) is 7 in the list [1, 3, 5, 7, 9]? (4) is 4 not in the same list? Print each result.**

# %%
print("py"in "python") #true
print("z" not in "python")#true
print(7 in [1,3,5,7,9])#true
print(4 not in [1,3,5,7,9])#true
# Out:
# True
# True
# True
# True

# %% [markdown]
# **11.Take the string s = '  python programming  '. In separate print statements, show: the stripped version, stripped + upper(), stripped + title(), stripped + replace('python', 'data'), and the length of the stripped string.**

# %%
s = 'python programming'
stripped = s.strip()
print(stripped)
print(stripped.upper())
print(stripped.title())
print(stripped.replace('python','data'))
print(len(stripped))
# Out:
# python programming
# PYTHON PROGRAMMING
# Python Programming
# data programming
# 18

# %% [markdown]
# **Problem 12:  Given text = 'Data,Science,Machine,Learning' - split it into a list, print the list, print the second element, print the total number of elements, then join the list back with ' → ' as separator.**

# %%
text='Data,Science,Machine,Learning'
lst= text.split(',')
print(lst)
print(lst[1])
print(len(lst))
print(' → '.join(lst))
# Out:
# ['Data', 'Science', 'Machine', 'Learning']
# Science
# 4
# Data → Science → Machine → Learning

# %% [markdown]
# **Problem 13:  Given sentence = 'Hello World Python' - use slicing to print: the first 5 characters, the last 6 characters, every second character, and the entire string reversed.**

# %%
sentence = "Hello World Python"
print(sentence[:5])
print(sentence[-6:])
print(sentence[::2])
print(sentence[::-1])
# Out:
# Hello
# Python
# HloWrdPto
# nohtyP dlroW olleH

# %% [markdown]
# **Problem 14:  For the string word = 'Banana' - print the result of: find('a'), count('a'), startswith('Ba'), endswith('na'), isdigit(). Then check if '12345'.isdigit() is different from '123a5'.isdigit().**

# %%
word ="Banana"
print(word.find("a"))
print(word.count("a"))
print(word.startswith("Ba"))
print(word.endswith("na"))
print(word.isdigit())

print("12345".isdigit())
print("123a5".isdigit())
# Out:
# 1
# 3
# True
# True
# False
# True
# False

# %% [markdown]
# Problem 15:  Create three variables: product = 'Laptop', price = 75000.5, discount = 10. Print a formatted line using all three string formatting styles (f-string, .format(), % operator) showing: 'Product: Laptop | Price: 75000.50 | Discount: 10%'.
# Hint: Use :.2f for price formatting in all three styles.

# %%
product ='Laptop'
price =75000.5
discount =10
print(f'Product:{product}|Price:{price:.2f}|Discount:{discount}%')
print('Product:{}|Price:{:.2f}|Discount:{}%'.format(product,price,discount))
print('Product:%s|Price:%.2f|Discount:%d%%'% (product,price,discount))
# Out:
# Product:Laptop|Price:75000.50|Discount:10%
# Product:Laptop|Price: 75000.50|Discount:10%
# Product:Laptop|Price: 75000.50|Discount:10%

# %% [markdown]
# Module: Input / Output
#
# Problem 16:  Write a program that takes the user's name and birth year as input.

# %%
name = input("Enter your Name: ")
birth_year = int(input("Enter Birth Year: "))
age = 2025-birth_year
print("Hello", name + "!", "You are approximately", age, "years old.")
# Out:
# Enter your Name: Sumu
# Enter Birth Year: 2005
# Hello Sumu! You are approximately 20 years old.

# %%
name = input("Enter your Name: ")
birth_year = int(input("Enter Birth Year: "))
age = 2025-birth_year
print("Hello", name + "!", "You are approximately", age, "years old.")
# Out:
# Enter your Name: Jannat
# Enter Birth Year: 2009
# Hello Jannat! You are approximately 16 years old.

# %% [markdown]
# **Problem 17:  Build a simple area calculator. Ask the user to enter length and width (as floats). Calculate area and perimeter of the rectangle.**

# %%
length = float(input("Enter length:"))
width = float(input("Enter width:"))
area = length*width
perimeter =2*(length + width)
print(f'Area:{area:.2f}')
print(f'Perimeter:{perimeter:.2f}')
# Out:
# Enter length:2.5
# Enter width:5
# Area:12.50
# Perimeter:15.00

# %%
length = float(input("Enter length:"))
width = float(input("Enter width:"))
area = length*width
perimeter =2*(length + width)
print(f'Area:{area:.2f}')
print(f'Perimeter:{perimeter:.2f}')
# Out:
# Enter length:56
# Enter width:32.7
# Area:1831.20
# Perimeter:177.40

# %% [markdown]
# **Problem 18:  Take a score (0 - 100) from the user and print a grade using if-elif-else: 90–100 → 'A+', 80–89 → 'A', 60–79 → 'B', 40–59 → 'C', below 40 → 'F'. Also print 'Pass' or 'Fail' based on score >= 40.**

# %%
score = int(input("Enter your score:"))
if score >= 90:
    grade = 'A+'
elif score >= 80:
    grade = 'A'
elif score >= 60:
    grade = 'B'
elif score >= 40:
    grade = 'C'
else:
    grade = 'F'

print(f'Grade: {grade}')

if score >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your score:89
# Grade: A
# Pass

# %%
score = int(input("Enter your score:"))
if score >= 90:
    grade = 'A+'
elif score >= 80:
    grade = 'A'
elif score >= 60:
    grade = 'B'
elif score >= 40:
    grade = 'C'
else:
    grade = 'F'

print(f'Grade: {grade}')

if score >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter your score:33
# Grade: F
# Fail

# %% [markdown]
# **Problem 19:  Write a login system. Store a correct username and password in two variables. Take username and password input from the user. Using nested if-else: if username matches → check password → print 'Access Granted' or 'Wrong Password'; if username doesn't match → print 'User Not Found'.**

# %%
correct_username ="Messi"
correct_password ="Worldcup_Winner"
username=input("Enter username: ")
password=input("Enter password: ")
if username == correct_username:
    if password == correct_password:
        print('Access Granted')
    else:
        print('Wrong Password')
else:
    print('User Not Found')
# Out:
# Enter username: Sumaia
# Enter password: 1234
# User Not Found

# %%
correct_username ="Messi"
correct_password ="Worldcup_Winner"
username=input("Enter username:")
password=input("Enter password:")
if username ==correct_username:
    if password ==correct_password:
        print('Access Granted')
    else:
        print('Wrong Password')
else:
    print('User Not Found')
# Out:
# Enter username: Messi
# Enter password: Worldcup_Winner
# Access Granted

# %%
correct_username ="Messi"
correct_password ="Worldcup_Winner"
username=input("Enter username: ")
password=input("Enter password: ")
if username == correct_username:
    if password == correct_password:
        print('Access Granted')
    else:
        print('Wrong Password')
else:
    print('User Not Found')
# Out:
# Enter username: Messi
# Enter password: 1234
# Wrong Password

# %% [markdown]
# **Problem 20:  Take any number from the user. Using a single line ternary expression, print whether it is 'Positive', 'Negative', or 'Zero'. Then separately, using nested if-elif-else, also check if the number is even or odd (only if it is not zero).**

# %%
number= int(input("Enter a number:"))
result="Positive" if n > 0 else ("Negative" if n < 0 else "Zero")
print(result)
if number!=0:
    if number% 2==0:
        print("Even")
    else:
        print("Odd")
# Out:
# Enter a number:11
# Positive
# Odd

# %%
number= int(input("Enter a number:"))
result="Positive" if number > 0 else ("Negative" if number < 0 else "Zero")
print(result)
if number!=0:
    if number% 2==0:
        print("Even")
    else:
        print("Odd")
# Out:
# Enter a number:-9
# Negative
# Odd
